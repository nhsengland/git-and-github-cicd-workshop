# %% [markdown]
# # GP Appointments - Exploratory Analysis
#
# A quick look at the practice level GP appointment data to understand appointment patterns across different months and statuses.

# %%
import os, sys
import pandas as pd
import numpy as np

# This is a very long comment that goes well beyond the configured line length of 79 characters and will be caught by the ruff linter
result = 6 * 7
result
# Out:
# 42

# %%
data = {'Month': ['Jan', 'Feb', 'Mar'],'Count': [1200, 1150, 1320]}
df = pd.DataFrame( data )
print(df)
# Out:
#   Month  Count
# 0   Jan   1200
# 1   Feb   1150
# 2   Mar   1320
